# %%
from yahoo_fantasy_api import League, Team
from yahoo_oauth import OAuth2

# %%
oauth = OAuth2(None, None, from_file='../auth/oauth2yahoo.json')
league = League(oauth, league_id='461.l.6288') #game_key.l.leauge_key
# Out:
# [2025-11-19 22:30:42,215 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# [2025-11-19 22:30:42,217 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 384.5157129764557
# [2025-11-19 22:30:42,218 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID

# %%
my_team_code = "461.l.6288.t.4" #game_key.l.league_key.t.team_key
team = Team(oauth, team_key=my_team_code)
team.details()
# Out:
# {'team_key': '461.l.6288.t.4',
#  'team_id': '4',
#  'name': 'Gotham City Knights',
#  'url': 'https://football.fantasysports.yahoo.com/f1/6288/4',
#  'team_logos': [{'team_logo': {'size': 'large',
#     'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/7d719f2e4062b3f070897f74a6de4250d5072b61785623abdb3af93254cd4140.jpg'}}],
#  'previous_season_team_rank': 6,
#  'division_id': '1',
#  'number_of_moves': 22,
#  'number_of_trades': 0,
#  'roster_adds': {'coverage_type': 'week', 'coverage_value': 12, 'value': '0'},
#  'league_scoring_type': 'head',
#  'has_draft_grade': 1,
#  'draft_grade': 'C',
#  'draft_recap_url': 'https://football.fantasysports.yahoo.com/f1/6288/4/draftrecap',
#  'managers': [{'manager': {'manager_id': '4',
#     'nickname': 'Conner Muraglio',
#     'guid': '3WCJ2JANFYGT5XGKDASK3C67VA',
#     'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#     'felo_score': '776',
#     'felo_tier': 'gold'}}]}

# %%
import pandas as pd

# %%
roster = team.roster(1) #not sure why this needs a 1, works for all without it except team 4
players = pd.json_normalize(roster)
print(players)
# Out:
#     player_id                name status position_type eligible_positions  \
# 0       32723         Jalen Hurts                    O               [QB]
# 1       29399         Tyreek Hill     IR             O   [WR, W/R, W/R/T]
# 2       41793   Tetairoa McMillan                    O   [WR, W/R, W/R/T]
# 3       34120      Kyren Williams                    O   [RB, W/R, W/R/T]
# 4       30295     Aaron Jones Sr.                    O   [RB, W/R, W/R/T]
# 5       40064         Sam LaPorta     IR             O        [TE, W/R/T]
# 6       30996       Calvin Ridley     IR             O   [WR, W/R, W/R/T]
# 7       31896          DK Metcalf                    O   [WR, W/R, W/R/T]
# 8       33967    Jameson Williams                    O   [WR, W/R, W/R/T]
# 9       30161           Joe Mixon  NFI-R             O   [RB, W/R, W/R/T]
# 10      40889   Michael Penix Jr.     IR             O               [QB]
# 11      32705       D'Andre Swift      Q             O   [RB, W/R, W/R/T]
# 12      28392        Amari Cooper     NA             O   [WR, W/R, W/R/T]
# 13      40126          Josh Downs                    O   [WR, W/R, W/R/T]
# 14      40915     Adonai Mitchell                    O   [WR, W/R, W/R/T]
# 15      41009       Troy Franklin                    O   [WR, W/R, W/R/T]
# 16      31107      Dalton Schultz                    O        [TE, W/R/T]
# 17      41935         Jaydon Blue                    O   [RB, W/R, W/R/T]
# 18      41937          DJ Giddens                    O   [RB, W/R, W/R/T]
# 19      41951      Oronde Gadsden                    O        [TE, W/R/T]
# 20      42368     Xavier Restrepo     NA             O   [WR, W/R, W/R/T]
# 21      33537      Evan McPherson                    K                [K]
# 22     100020            New York                   DT              [DEF]
# 23      33969       Kyle Hamilton      Q            DP               [DB]
# 24      32741    Nnamdi Madubuike     IR            DP               [DL]
# 25      32735        Logan Wilson                   DP               [LB]
# 26      41818  Carson Schwesinger                   DP               [LB]
# 27      41844          Mike Green                   DP           [DL, LB]
#
#    selected_position
# 0                 QB
# 1                 WR
# 2                 WR
# 3                 RB
# 4                 RB
# 5                 TE
# 6                W/R
# 7              W/R/T
# 8                 BN
# 9                 BN
# 10                BN
# 11                BN
# 12                BN
# 13                BN
# 14                BN
# 15                BN
# 16                BN
# 17                BN
# 18                BN
# 19                BN
# 20                BN
# 21                 K
# 22               DEF
# 23                DB
# 24                DL
# 25                LB
# 26                BN
# 27                BN

# %%
#get player id's to use for data querying
player_id_list = players['player_id'].tolist()
player_stats_2025 = league.player_stats(player_id_list, req_type='season', season=2025)

# %%
#create a dataframe of the normalized stats
df = pd.json_normalize(player_stats_2025)
df.fillna(0, inplace=True)
df['total_points'] = pd.to_numeric(df['total_points']) #values were str causing issues with sorting
# print(df)

# %%
#table is large, check just columns that we have in table to see what is important
print(df.columns)
# Out:
# Index(['player_id', 'name', 'position_type', 'Pass Yds', 'Pass TD', 'Int',
#        'Rush Att', 'Rush Yds', 'Rush TD', 'Targets', 'Rec', 'Rec Yds',
#        'Rec TD', 'Ret Yds', 'Ret TD', '2-PT', 'Fum Lost', 'Fum Ret TD',
#        'total_points', 'FG 0-19', 'FG 20-29', 'FG 30-39', 'FG 40-49', 'FG 50+',
#        'PAT Made', 'Pts Allow', 'Sack', 'Fum Rec', 'TD', 'Safe', 'Blk Kick',
#        'TFL', 'Def Yds Allow', '3 and Outs', 'Pts Allow 0', 'Pts Allow 1-6',
#        'Pts Allow 7-13', 'Pts Allow 14-20', 'Pts Allow 21-27',
#        'Pts Allow 28-34', 'Pts Allow 35+', 'Yds Allow Neg', 'Yds Allow 0-99',
#        'Yds Allow 100-199', 'Yds Allow 200-299', 'Yds Allow 300-399',
#        'Yds Allow 400-499', 'Yds Allow 500+', 'XPR', 'Tack Solo', 'Tack Ast',
#        'Fum Force', 'Pass Def', 'TO Ret Yds'],
#       dtype='object')

# %%
player_by_total_points = df[['name','total_points']]
print(player_by_total_points.sort_values('total_points',ascending=False))
# Out:
#                   name  total_points
# 22            New York        286.90
# 0          Jalen Hurts        232.30
# 3       Kyren Williams        166.20
# 2    Tetairoa McMillan        153.80
# 10   Michael Penix Jr.        138.28
# 11       D'Andre Swift        135.40
# 15       Troy Franklin        132.80
# 7           DK Metcalf        125.10
# 8     Jameson Williams        119.20
# 5          Sam LaPorta        107.90
# 16      Dalton Schultz        107.40
# 19      Oronde Gadsden         97.70
# 13          Josh Downs         89.10
# 26  Carson Schwesinger         79.60
# 21      Evan McPherson         68.00
# 4      Aaron Jones Sr.         62.30
# 23       Kyle Hamilton         56.50
# 1          Tyreek Hill         55.40
# 6        Calvin Ridley         47.30
# 25        Logan Wilson         37.50
# 14     Adonai Mitchell         25.20
# 27          Mike Green         22.00
# 17         Jaydon Blue         15.20
# 24    Nnamdi Madubuike         10.00
# 18          DJ Giddens          6.60
# 9            Joe Mixon          0.00
# 12        Amari Cooper          0.00
# 20     Xavier Restrepo          0.00
