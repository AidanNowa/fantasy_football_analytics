# %%
import logging
from yahoo_oauth import OAuth2
from yahoo_fantasy_api import Team

# %%
#enable debug logging
logging.basicConfig(level=logging.DEBUG)

# %%
my_team_code = "461.l.6288.t.4"
oauth = OAuth2(None, None, from_file='../auth/oauth2yahoo.json')
curr_week = 11
team = Team(oauth, team_key=my_team_code)
roster = team.roster(week=curr_week)
# Out:
# [2025-11-28 12:11:49,816 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# DEBUG:yahoo_oauth:Checking
# [2025-11-28 12:11:49,819 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 38.17694306373596
# DEBUG:yahoo_oauth:ELAPSED TIME : 38.17694306373596
# [2025-11-28 12:11:49,821 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# DEBUG:yahoo_oauth:TOKEN IS STILL VALID
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): fantasysports.yahooapis.com:443
# DEBUG:urllib3.connectionpool:https://fantasysports.yahooapis.com:443 "GET /fantasy/v2/team/461.l.6288.t.4/roster;week=11?format=json HTTP/1.1" 200 7359

# %%
my_team_code = "461.l.6288.t.4"
oauth = OAuth2(None, None, from_file='../auth/oauth2yahoo.json')
curr_week = 11
team = Team(oauth, team_key=my_team_code)
roster = team.roster(week=curr_week)
# Out:
# [2025-11-28 12:11:50,056 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# DEBUG:yahoo_oauth:Checking
# [2025-11-28 12:11:50,059 DEBUG] [yahoo_oauth.oauth.token_is_valid] ELAPSED TIME : 38.416590213775635
# DEBUG:yahoo_oauth:ELAPSED TIME : 38.416590213775635
# [2025-11-28 12:11:50,061 DEBUG] [yahoo_oauth.oauth.token_is_valid] TOKEN IS STILL VALID
# DEBUG:yahoo_oauth:TOKEN IS STILL VALID
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): fantasysports.yahooapis.com:443
# DEBUG:urllib3.connectionpool:https://fantasysports.yahooapis.com:443 "GET /fantasy/v2/team/461.l.6288.t.4/roster;week=11?format=json HTTP/1.1" 200 7358

# %%
print(roster)
# Out:
# [{'player_id': 32723, 'name': 'Jalen Hurts', 'position_type': 'O', 'eligible_positions': ['QB'], 'status': '', 'selected_position': 'QB'}, {'player_id': 41793, 'name': 'Tetairoa McMillan', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T'], 'status': '', 'selected_position': 'WR'}, {'player_id': 33967, 'name': 'Jameson Williams', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T'], 'status': '', 'selected_position': 'WR'}, {'player_id': 34120, 'name': 'Kyren Williams', 'position_type': 'O', 'eligible_positions': ['RB', 'W/R', 'W/R/T'], 'status': '', 'selected_position': 'RB'}, {'player_id': 30295, 'name': 'Aaron Jones Sr.', 'position_type': 'O', 'eligible_positions': ['RB', 'W/R', 'W/R/T'], 'status': '', 'selected_position': 'RB'}, {'player_id': 41951, 'name': 'Oronde Gadsden', 'position_type': 'O', 'eligible_positions': ['TE', 'W/R/T'], 'status': '', 'selected_position': 'TE'}, {'player_id': 42389, 'name': 'Myles Price', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T'], 'status': '', 'selected_position': 'W/R'}, {'player_id': 42030, 'name': 'Tez Johnson', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T'], 'status': '', 'selected_position': 'W/R/T'}, {'player_id': 30996, 'name': 'Calvin Ridley', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T'], 'status': 'IR', 'selected_position': 'BN'}, {'player_id': 40126, 'name': 'Josh Downs', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T'], 'status': '', 'selected_position': 'BN'}, {'player_id': 40889, 'name': 'Michael Penix Jr.', 'position_type': 'O', 'eligible_positions': ['QB'], 'status': 'IR', 'selected_position': 'BN'}, {'player_id': 28592, 'name': 'Darren Waller', 'position_type': 'O', 'eligible_positions': ['TE', 'W/R/T'], 'status': 'IR-R', 'selected_position': 'BN'}, {'player_id': 29399, 'name': 'Tyreek Hill', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T'], 'status': 'IR', 'selected_position': 'BN'}, {'player_id': 31107, 'name': 'Dalton Schultz', 'position_type': 'O', 'eligible_positions': ['TE', 'W/R/T'], 'status': '', 'selected_position': 'BN'}, {'player_id': 30161, 'name': 'Joe Mixon', 'position_type': 'O', 'eligible_positions': ['RB', 'W/R', 'W/R/T'], 'status': 'NFI-R', 'selected_position': 'BN'}, {'player_id': 99001, 'name': 'Travis Hunter', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T', 'DB'], 'status': 'IR', 'selected_position': 'BN'}, {'player_id': 31157, 'name': 'Ray-Ray McCloud', 'position_type': 'O', 'eligible_positions': ['WR', 'W/R', 'W/R/T'], 'status': 'NA', 'selected_position': 'BN'}, {'player_id': 33537, 'name': 'Evan McPherson', 'position_type': 'K', 'eligible_positions': ['K'], 'status': '', 'selected_position': 'K'}, {'player_id': 40159, 'name': 'Chad Ryland', 'position_type': 'K', 'eligible_positions': ['K'], 'status': '', 'selected_position': 'BN'}, {'player_id': 100008, 'name': 'Detroit', 'position_type': 'DT', 'eligible_positions': ['DEF'], 'status': '', 'selected_position': 'DEF'}, {'player_id': 100020, 'name': 'New York', 'position_type': 'DT', 'eligible_positions': ['DEF'], 'status': '', 'selected_position': 'BN'}, {'player_id': 100019, 'name': 'New York', 'position_type': 'DT', 'eligible_positions': ['DEF'], 'status': '', 'selected_position': 'BN'}, {'player_id': 33969, 'name': 'Kyle Hamilton', 'position_type': 'DP', 'eligible_positions': ['DB'], 'status': '', 'selected_position': 'DB'}, {'player_id': 40124, 'name': 'Byron Young', 'position_type': 'DP', 'eligible_positions': ['DL', 'LB'], 'status': 'Q', 'selected_position': 'DL'}, {'player_id': 31837, 'name': 'Devin White', 'position_type': 'DP', 'eligible_positions': ['LB'], 'status': '', 'selected_position': 'LB'}, {'player_id': 41818, 'name': 'Carson Schwesinger', 'position_type': 'DP', 'eligible_positions': ['LB'], 'status': 'Q', 'selected_position': 'BN'}, {'player_id': 32735, 'name': 'Logan Wilson', 'position_type': 'DP', 'eligible_positions': ['LB'], 'status ...
